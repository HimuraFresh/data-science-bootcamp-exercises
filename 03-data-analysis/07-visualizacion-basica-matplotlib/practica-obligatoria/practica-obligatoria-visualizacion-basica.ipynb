# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: **Visualización Básica**

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en un único ejercicio de construcción de gráficas. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# #### #1.1
#
# - Carga el dataset de casas de California que está en la ruta "./data/california_cities.csv".
# - Muestra parte de su contenido y su descripción.
# - Deshazte de las filas con nulos.

# %%
df = pd.read_csv("./data/california_cities.csv", index_col=0)
df
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778        875.0        2871.0
# 1    AgouraHills  34.153333 -118.761667        281.0         922.0
# 2        Alameda  37.756111 -122.274444          NaN          33.0
# 3         Albany  37.886944 -122.297778          NaN          43.0
# 4       Alhambra  34.081944 -118.135000        150.0         492.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# 1               20330             7.822            7.793             0.029
# 2               75467            22.960           10.611            12.349
# 3               18969             5.465            1.788             3.677
# 4               83089             7.632            7.631             0.001
# ..                ...               ...              ...               ...
# 477              2933             1.531            1.531             0.000
# 478              7765            10.053            9.980             0.073
# 479             64925            14.656           14.578             0.078
# 480             51367            27.893           27.888             0.005
# 481             20700            40.015           40.015             0.000
#
#      area_total_km2  area_land_km2  area_water_km2  area_water_percent
# 0           145.107        145.062           0.046                0.03
# 1            20.260         20.184           0.076                0.37
# 2            59.465         27.482          31.983               53.79
# 3            14.155          4.632           9.524               67.28
# 4            19.766         19.763           0.003                0.01
# ..              ...            ...             ...                 ...
# 477           3.966          3.966           0.000                0.00
# 478          26.036         25.847           0.188                0.72
# 479          37.959         37.758           0.201                0.53
# 480          72.244         72.231           0.013                0.02
# 481         103.639        103.639           0.000                0.00
#
# [482 rows x 13 columns]

# %%
df.head()
# Out:
#           city       latd       longd  elevation_m  elevation_ft  \
# 0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2      Alameda  37.756111 -122.274444          NaN          33.0
# 3       Albany  37.886944 -122.297778          NaN          43.0
# 4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
#    area_total_km2  area_land_km2  area_water_km2  area_water_percent
# 0         145.107        145.062           0.046                0.03
# 1          20.260         20.184           0.076                0.37
# 2          59.465         27.482          31.983               53.79
# 3          14.155          4.632           9.524               67.28
# 4          19.766         19.763           0.003                0.01

# %%
df.describe()
# Out:
#              latd       longd  elevation_m  elevation_ft  population_total  \
# count  482.000000  482.000000   434.000000    470.000000      4.820000e+02
# mean    36.095088 -119.837714   180.416705    567.168723      6.489493e+04
# std      2.298006    2.147676   309.531825   1001.265722      2.032041e+05
# min     32.578333 -124.263333   -34.000000   -180.000000      1.000000e+00
# 25%     33.977292 -121.954931    22.000000     69.000000      1.090200e+04
# 50%     36.204722 -119.708611    67.000000    200.000000      2.905750e+04
# 75%     37.886667 -117.977292   173.500000    515.000000      6.646650e+04
# max     41.965000 -114.596389  2402.000000   7880.000000      3.884307e+06
#
#        area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  area_total_km2  \
# count        480.000000       482.000000        481.000000      477.000000
# mean          18.442183        16.840981          1.589630       46.753283
# std           36.363230        32.694647          9.490386       90.972269
# min            0.314000         0.314000          0.000000        0.813000
# 25%            3.708250         3.506500          0.000000        9.551000
# 50%            9.093000         8.362000          0.029000       23.551000
# 75%           19.878250        19.090000          0.244000       51.772000
# max          503.000000       469.000000        185.020000     1302.000000
#
#        area_land_km2  area_water_km2  area_water_percent
# count     478.000000      478.000000          477.000000
# mean       43.547021        3.125178            5.301801
# std        84.933022       11.562269           14.656428
# min         0.813000        0.000000            0.000000
# 25%         9.025000        0.000250            0.000000
# 50%        21.533000        0.078500            0.340000
# 75%        49.322000        0.623250            1.870000
# max      1214.000000      122.270000           84.580000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 482 entries, 0 to 481
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   city                482 non-null    object
#  1   latd                482 non-null    float64
#  2   longd               482 non-null    float64
#  3   elevation_m         434 non-null    float64
#  4   elevation_ft        470 non-null    float64
#  5   population_total    482 non-null    int64
#  6   area_total_sq_mi    480 non-null    float64
#  7   area_land_sq_mi     482 non-null    float64
#  8   area_water_sq_mi    481 non-null    float64
#  9   area_total_km2      477 non-null    float64
#  10  area_land_km2       478 non-null    float64
#  11  area_water_km2      478 non-null    float64
#  12  area_water_percent  477 non-null    float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 52.7+ KB

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# elevation_m           48
# elevation_ft          12
# area_water_percent     5
# area_total_km2         5
# area_water_km2         4
# area_land_km2          4
# area_total_sq_mi       2
# area_water_sq_mi       1
# city                   0
# latd                   0
# longd                  0
# area_land_sq_mi        0
# population_total       0
# dtype: int64

# %%
df["elevation_m"]
# Out:
# 0       875.0
# 1       281.0
# 2         NaN
# 3         NaN
# 4       150.0
#         ...
# 477      30.0
# 478     787.0
# 479      18.0
# 480     798.0
# 481    1027.0
# Name: elevation_m, Length: 482, dtype: float64

# %%
df["elevation_m_from_ft"] = (df["elevation_ft"] * 0.3048).round(1)

# %%
df.loc[df["elevation_m"].isna()]
# Out:
#                     city       latd       longd  elevation_m  elevation_ft  \
# 2                Alameda  37.756111 -122.274444          NaN          33.0
# 3                 Albany  37.886944 -122.297778          NaN          43.0
# 15                Arcata  40.866389 -124.082778          NaN          23.0
# 26           Bakersfield  35.366667 -119.016667          NaN         404.0
# 41                Bishop  37.363500 -118.395100          NaN        4150.0
# 47             Brentwood  37.931944 -121.695833          NaN          79.0
# 54              Calexico  32.678889 -115.498889          NaN           3.0
# 57            Calipatria  33.125556 -115.514167          NaN        -180.0
# 64        CarmelbytheSea  36.555278 -121.923333          NaN           NaN
# 76             Claremont  34.110000 -117.719722          NaN           NaN
# 79            Cloverdale  38.799167 -123.017222          NaN         335.0
# 98          CrescentCity  41.755833 -124.201667          NaN          43.0
# 118               Dublin  37.702222 -121.935833          NaN         367.0
# 121             Eastvale  33.963056 -117.563889          NaN         627.0
# 124            ElCerrito  37.915833 -122.311667          NaN          69.0
# 133               Eureka  40.801944 -124.163611          NaN          39.0
# 150               Fresno  36.750000 -119.766667          NaN         308.0
# 158               Goleta  34.440556 -119.813611          NaN          20.0
# 171              Hayward  37.668889 -122.080833          NaN         105.0
# 197         JurupaValley  33.999444 -117.475278          NaN           NaN
# 201    LaCaadaFlintridge  34.207721 -118.206979          NaN           NaN
# 219             Larkspur  37.934167 -122.535278          NaN          43.0
# 227  LiveOakSutterCounty  39.275833 -121.660000          NaN          79.0
# 228            Livermore  37.681944 -121.768056          NaN         495.0
# 234            LongBeach  33.768333 -118.195556          NaN           0.0
# 237             LosAltos  37.368056 -122.097500          NaN         157.0
# 259             Millbrae  37.600833 -122.401389          NaN          33.0
# 260           MillValley  37.906111 -122.545000          NaN          79.0
# 270          MonteSereno  37.238056 -121.989444          NaN         515.0
# 272               Moraga  37.835000 -122.129722          NaN           NaN
# 279                 Napa  38.304722 -122.298889          NaN          20.0
# 283               Newark  37.533333 -122.033333          NaN          20.0
# 290              Oakland  37.804444 -122.270833          NaN          43.0
# 317             Piedmont  37.816667 -122.233333          NaN         331.0
# 322          Placerville  38.729722 -120.798611          NaN        1867.0
# 324           Pleasanton  37.662500 -121.874722          NaN         351.0
# 341         RedondoBeach  33.856389 -118.376944          NaN          62.0
# 364            SanCarlos  37.499167 -122.263333          NaN          33.0
# 368             SanDimas  34.102778 -117.816111          NaN         750.0
# 370         SanFrancisco  37.783333 -122.416667          NaN          52.0
# 372               Sanger  36.708056 -119.555833          NaN         371.0
# 380            SanMarcos  33.141944 -117.170278          NaN           NaN
# 393          SantaMonica  34.021944 -118.481389          NaN         105.0
# 397             Saratoga  37.272500 -122.019444          NaN         410.0
# 443            UnionCity  37.586944 -122.025833          NaN           NaN
# 447              Ventura  34.275000 -119.227778          NaN           NaN
# 454          WalnutCreek  37.906389 -122.065000          NaN         131.0
# 463          Westmorland  33.037222 -115.621389          NaN        -164.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 2               75467            22.960           10.611            12.349
# 3               18969             5.465            1.788             3.677
# 15              17231            10.994            9.097             1.897
# 26             347483           143.609          142.164             1.445
# 41               3879             1.911            1.864             0.047
# 47              51481            14.805           14.786             0.019
# 54              38572             8.391            8.391             0.000
# 57               7705             3.716            3.716             0.000
# 64               3722             1.080            1.080             0.000
# 76              34926            13.486           13.348             0.138
# 79               8618             2.648            2.648             0.000
# 98               7643             2.415            1.963             0.452
# 118             49890            14.912           14.908             0.004
# 121             53668            11.445           11.405             0.040
# 124             23549             3.688            3.688             0.000
# 133             27191            14.454            9.384             5.070
# 150            509039           112.308          111.957             0.351
# 158             29888             7.975            7.903             0.072
# 171            149392            63.748           45.323            18.425
# 197             97496            43.500           43.300             0.200
# 201             20246             8.645            8.628             0.017
# 219             11926             3.243            3.027             0.216
# 227              8392             1.869            1.869             0.000
# 228             83547            25.176           25.173             0.003
# 234            462257            51.437           50.293             1.144
# 237             28976             6.487            6.487             0.000
# 259             21536             3.259            3.247             0.012
# 260             13903             4.847            4.763             0.084
# 270              3341             1.615            1.615             0.000
# 272             16016             9.442            9.433             0.009
# 279             76915            18.147           17.839             0.308
# 283             43539            13.898           13.875             0.023
# 290            406253            78.002           55.786            22.216
# 317             10667             1.678            1.678             0.000
# 322             10389             5.813            5.812             0.001
# 324             70285            24.266           24.113             0.153
# 341             66748             6.208            6.198             0.010
# 364             28406             5.541            5.538             0.003
# 368             33371            15.427           15.037             0.390
# 370            837442           231.890           46.870           185.020
# 372             24270             5.524            5.524             0.000
# 380             83781            24.390           24.370             0.020
# 393             89736             8.416            8.415             0.001
# 397             29926            12.382           12.382             0.000
# 443             72155            19.000           19.000             0.000
# 447            106433            32.095           21.655            10.440
# 454             64173            19.769           19.757             0.012
# 463              2225             0.590            0.590             0.000
#
#      area_total_km2  area_land_km2  area_water_km2  area_water_percent  \
# 2            59.465         27.482          31.983               53.79
# 3            14.155          4.632           9.524               67.28
# 15           28.473         23.561           4.912               17.25
# 26          371.946        368.204           3.742                1.01
# 41            4.949          4.827           0.122                2.50
# 47           38.345         38.295           0.049                0.13
# 54           21.733         21.733           0.000                0.00
# 57            9.624          9.624           0.000                0.00
# 64            2.798          2.798           0.000                0.00
# 76           34.930         34.571           0.358                1.03
# 79            6.857          6.857           0.000                0.00
# 98            6.255          5.085           1.170               18.70
# 118          38.622         38.611           0.011                0.03
# 121          29.644         29.539           0.104                0.35
# 124           9.551          9.551           0.000                0.00
# 133          37.435         24.305          13.130               35.07
# 150         290.877        289.967           0.910                0.31
# 158          20.654         20.467           0.187                0.90
# 171         165.108        117.386          47.721               28.90
# 197         112.700        112.100           0.600                 NaN
# 201          22.391         22.347           0.044                0.20
# 219           8.399          7.840           0.560                6.66
# 227           4.839          4.839           0.000                0.00
# 228          65.204         65.198           0.007                0.01
# 234         133.223        130.259           2.964                2.22
# 237             NaN            NaN             NaN                 NaN
# 259           8.439          8.409           0.030                0.36
# 260          12.555         12.336           0.219                1.74
# 270           4.184          4.184           0.000                0.00
# 272          24.455         24.432           0.023                0.09
# 279          47.000         46.203           0.797                1.69
# 283          35.996         35.936           0.061                0.17
# 290         202.024        144.485          57.540               28.48
# 317           4.345          4.345           0.000                0.00
# 322          15.054         15.052           0.002                0.01
# 324          62.847         62.452           0.395                0.63
# 341          16.080         16.054           0.026                0.16
# 364          14.350         14.343           0.007                0.05
# 368          39.957         38.947           1.010                2.53
# 370             NaN            NaN             NaN               80.00
# 372          14.307         14.307           0.000                0.00
# 380          63.169         63.117           0.053                0.08
# 393             NaN            NaN             NaN                 NaN
# 397          32.070         32.070           0.000                0.00
# 443             NaN            NaN             NaN                 NaN
# 447          83.124         56.085          27.039               32.53
# 454          51.201         51.169           0.031                0.06
# 463           1.529          1.529           0.000                0.00
#
#      elevation_m_from_ft
# 2                   10.1
# 3                   13.1
# 15                   7.0
# 26                 123.1
# 41                1264.9
# 47                  24.1
# 54                   0.9
# 57                 -54.9
# 64                   NaN
# 76                   NaN
# 79                 102.1
# 98                  13.1
# 118                111.9
# 121                191.1
# 124                 21.0
# 133                 11.9
# 150                 93.9
# 158                  6.1
# 171                 32.0
# 197                  NaN
# 201                  NaN
# 219                 13.1
# 227                 24.1
# 228                150.9
# 234                  0.0
# 237                 47.9
# 259                 10.1
# 260                 24.1
# 270                157.0
# 272                  NaN
# 279                  6.1
# 283                  6.1
# 290                 13.1
# 317                100.9
# 322                569.1
# 324                107.0
# 341                 18.9
# 364                 10.1
# 368                228.6
# 370                 15.8
# 372                113.1
# 380                  NaN
# 393                 32.0
# 397                125.0
# 443                  NaN
# 447                  NaN
# 454                 39.9
# 463                -50.0

# %%
df.loc[df["elevation_m"].isna(), ["city","elevation_m","elevation_ft"]]
# Out:
#                     city  elevation_m  elevation_ft
# 2                Alameda          NaN          33.0
# 3                 Albany          NaN          43.0
# 15                Arcata          NaN          23.0
# 26           Bakersfield          NaN         404.0
# 41                Bishop          NaN        4150.0
# 47             Brentwood          NaN          79.0
# 54              Calexico          NaN           3.0
# 57            Calipatria          NaN        -180.0
# 64        CarmelbytheSea          NaN           NaN
# 76             Claremont          NaN           NaN
# 79            Cloverdale          NaN         335.0
# 98          CrescentCity          NaN          43.0
# 118               Dublin          NaN         367.0
# 121             Eastvale          NaN         627.0
# 124            ElCerrito          NaN          69.0
# 133               Eureka          NaN          39.0
# 150               Fresno          NaN         308.0
# 158               Goleta          NaN          20.0
# 171              Hayward          NaN         105.0
# 197         JurupaValley          NaN           NaN
# 201    LaCaadaFlintridge          NaN           NaN
# 219             Larkspur          NaN          43.0
# 227  LiveOakSutterCounty          NaN          79.0
# 228            Livermore          NaN         495.0
# 234            LongBeach          NaN           0.0
# 237             LosAltos          NaN         157.0
# 259             Millbrae          NaN          33.0
# 260           MillValley          NaN          79.0
# 270          MonteSereno          NaN         515.0
# 272               Moraga          NaN           NaN
# 279                 Napa          NaN          20.0
# 283               Newark          NaN          20.0
# 290              Oakland          NaN          43.0
# 317             Piedmont          NaN         331.0
# 322          Placerville          NaN        1867.0
# 324           Pleasanton          NaN         351.0
# 341         RedondoBeach          NaN          62.0
# 364            SanCarlos          NaN          33.0
# 368             SanDimas          NaN         750.0
# 370         SanFrancisco          NaN          52.0
# 372               Sanger          NaN         371.0
# 380            SanMarcos          NaN           NaN
# 393          SantaMonica          NaN         105.0
# 397             Saratoga          NaN         410.0
# 443            UnionCity          NaN           NaN
# 447              Ventura          NaN           NaN
# 454          WalnutCreek          NaN         131.0
# 463          Westmorland          NaN        -164.0

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 427 entries, 0 to 481
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   city                 427 non-null    object
#  1   latd                 427 non-null    float64
#  2   longd                427 non-null    float64
#  3   elevation_m          427 non-null    float64
#  4   elevation_ft         427 non-null    float64
#  5   population_total     427 non-null    int64
#  6   area_total_sq_mi     427 non-null    float64
#  7   area_land_sq_mi      427 non-null    float64
#  8   area_water_sq_mi     427 non-null    float64
#  9   area_total_km2       427 non-null    float64
#  10  area_land_km2        427 non-null    float64
#  11  area_water_km2       427 non-null    float64
#  12  area_water_percent   427 non-null    float64
#  13  elevation_m_from_ft  427 non-null    float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 50.0+ KB

# %% [markdown]
# #### #1.2
#
# Recrea la siguiente figura, para ello construye en apartados separados cada gráfico y luego haz un apartado en el que se junten los cuatro.
#
# Las figuras son:
# 1. Las ciudades más pobladas, con los numeros de las poblaciones (tendrás que usar texto y recordar que para centrarlos se necesita poner el argumento `ha` a "center"). (Colores: azul, gris, aceituna, marrón, con trasparencia)
#
# 2. Histograma del área total ocupada por las ciudades. (50 bins, fuente = "Bradley Hand ITC", tamaño 18, color azul acero o "steelblue")
# 3. El scatter de área de agua de un ciudad con su poblacion.
# 4. El boxplot de la altura de las ciudades.

# %% [markdown]
# ![figura_ejempo.png](attachment:figura_ejempo.png)

# %% [markdown]
# 1. Las ciudades más pobladas, con los numeros de las poblaciones (tendrás que usar texto y recordar que para centrarlos se necesita poner el argumento `ha` a "center"). (Colores: azul, gris, rojo, aceituna, marrón, con trasparencia)

# %%
ciudades_mas_pobladas = df.loc[df.population_total.nlargest(5).index, ["city","population_total"]]
ciudades_mas_pobladas
# Out:
#            city  population_total
# 239  LosAngeles           3884307
# 367    SanDiego           1345895
# 359  Sacramento            466488
# 9       Anaheim            336000
# 386    SantaAna            324528

# %%
def separa_nombre(nombre):
    nuevo = nombre[0]
    for letra in nombre[1:]:
        if letra == letra.upper():
            nuevo += " "
        nuevo += letra
    return nuevo

# %%
separa_nombre("LosAngeles")
# Out:
# 'Los Angeles'

# %%
def separa_nombre(nombre):
    nuevo = nombre[0]
    for letra in nombre[1:]:
        if letra == letra.upper():
            nuevo += " "
        nuevo += letra
    return nuevo
    
ciudades_mas_pobladas = df.loc[df.population_total.nlargest(5).index, ["city","population_total"]]
ciudades = [separa_nombre(ciudad) for ciudad in ciudades_mas_pobladas["city"].to_list()]
colores = ["blue","gray","red","olive","brown"]

plt.figure(figsize = (8,5))

plt.bar(x= ciudades,
        height= ciudades_mas_pobladas["population_total"]/1000,
        color= colores,
        alpha= 0.5)

plt.ylim([0,5000])
plt.ylabel("Habitantes (miles)") 
plt.xlabel("Ciudades")
plt.title("Ciudades más pobladas de California")

ciudades_mas_pobladas.set_index("city", inplace= True)

for indice, ciudad in enumerate(ciudades_mas_pobladas.index):
    poblacion = ciudades_mas_pobladas.loc[ciudad, "population_total"]/1000
    plt.text(ciudades[indice], poblacion + 70, f"{poblacion}", ha = "center")

plt.show()

# %% [markdown]
# 2. Histograma del área total ocupada por las ciudades. (50 bins, fuente = "Bradley Hand ITC", tamaño 18, color azul acero o "steelblue")

# %%
import matplotlib
from pathlib import Path

# 1) Dónde está instalado matplotlib
print("matplotlib.py está en:")
print(matplotlib.__file__)

# 2) Carpeta de datos de matplotlib (donde están las fuentes)
data_path = matplotlib.get_data_path()
print("\nCarpeta mpl-data:")
print(data_path)

# 3) Carpeta concreta de fuentes TTF
ttf_dir = Path(data_path) / "fonts" / "ttf"
print("\nCarpeta de fuentes TTF:")
print(ttf_dir)
# Out:
# matplotlib.py está en:
# c:\Users\helad\OneDrive\Escritorio\DataSience\DS-Online-Roman\venv\Lib\site-packages\matplotlib\__init__.py
#
# Carpeta mpl-data:
# c:\Users\helad\OneDrive\Escritorio\DataSience\DS-Online-Roman\venv\Lib\site-packages\matplotlib\mpl-data
#
# Carpeta de fuentes TTF:
# c:\Users\helad\OneDrive\Escritorio\DataSience\DS-Online-Roman\venv\Lib\site-packages\matplotlib\mpl-data\fonts\ttf

# %%
# Bradley Hand Itc en legionfonts.com
# https://legionfonts.com/fonts/bradley-hand-itc

# Para usar la fuente en Matplotlib hay que instalarla en su propio fontmanager
# Para encontrar la ruta a la carpeta de fuentes de Matplotlib usar matplotlib.font_manager.findfondt

import matplotlib

# matplotlib.font_manager.findfondt('Bradley Hand Itc')
print(matplotlib.font_manager.findfont('Bradley Hand Itc'))
# Out:
# C:\Windows\Fonts\BRADHITC.TTF

# %%
import matplotlib
from matplotlib import font_manager as fm

# Fuerza recarga del font manager sin usar caché
fm._load_fontmanager(try_read_cache=False)

print(fm.findfont("Bradley Hand ITC"))
# Out:
# C:\Windows\Fonts\BRADHITC.TTF

# %%
df["area_total_km2"].hist()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8,8))

plt.hist(df["area_total_km2"],
         color = "steelblue",
         alpha = 0.7,
         bins = 50,
         label = "Hist Area")

plt.xlabel("Superficie ($km^2$)", fontdict = dict(family= "Bradley Hand ITC", size= 18))
plt.ylabel("Número de Ciudades", fontdict = dict(family= "Bradley Hand ITC", size= 18))
plt.legend()

plt.show()

# %% [markdown]
# 3. El scatter de área de agua de un ciudad con su poblacion.

# %%
ciudades_mas_pobladas.population_total.nlargest(2)
# Out:
# city
# LosAngeles    3884307
# SanDiego      1345895
# Name: population_total, dtype: int64

# %%
ciudades_mas_pobladas.population_total.nlargest(2).iloc[0]
# Out:
# np.int64(3884307)

# %%
ciudades_mas_pobladas.population_total.nlargest(2).iloc[0]
# Out:
# np.int64(3884307)

# %%
plt.figure(figsize=(8,8))


plt.scatter(x= df["area_water_km2"],
            y= df["population_total"]/1000,
            alpha= 0.5,
            color= "green")

plt.xlabel("Área de agua en la ciudad ($km^2$)")
plt.ylabel("Población (miles habitantes)")
plt.title("Poblaciín por kilomtero cuadrado de agua")

outlier_1_y = (df["population_total"]).nlargest(2).iloc[0]
outlier_2_y = (df["population_total"]).nlargest(2).iloc[1]
outlier_1_x =df.loc[df.population_total == outlier_1_y, "area_water_km2"].values[0]
outlier_2_x =df.loc[df.population_total == outlier_2_y, "area_water_km2"].values[0]

xytext= (55,2750)
text= "Outliers"

plt.annotate(xy= (outlier_1_x, outlier_1_y/1000),
             xytext= xytext,
             text= text,
             arrowprops= dict(arrowstyle = "->"))

plt.annotate(xy= (outlier_2_x, outlier_2_y/1000),
             xytext= xytext,
             text= " " * len(text),
             arrowprops= dict(arrowstyle = "->"))

plt.show()

# %% [markdown]
# 4. El boxplot de la altura de las ciudades.

# %%
plt.figure(figsize=(8,5))

plt.boxplot(df["elevation_m"],
            vert= False,
            patch_artist= True,
            boxprops= dict(facecolor = "red"),
            medianprops= dict(color= "black"))

plt.xlabel("Altitud (m)")
plt.title("Diagrama de caja de la Altitud de las ciudades de California")
plt.yticks([])


plt.show()

# %%
# Todas juntas
plt.figure(figsize=(20,20))

# Primera figura
plt.subplot(2, 2, 1)

ciudades_mas_pobladas = df.loc[df.population_total.nlargest(5).index, ["city", "population_total"]]
ciudades = [separa_nombre(ciudad) for ciudad in ciudades_mas_pobladas["city"].to_list()]
colores = ["blue", "gray", "red", "olive", "brown"]

plt.bar(x=ciudades, height=ciudades_mas_pobladas["population_total"]/1000, color=colores, alpha=0.5)

plt.ylim([0, 5000])
plt.ylabel("Habitantes (miles)")
plt.xlabel("Ciudades")
plt.title("Ciudades más pobladas de California")

ciudades_mas_pobladas.set_index("city", inplace=True)
for indice, ciudad in enumerate(ciudades_mas_pobladas.index):
    poblacion = ciudades_mas_pobladas.loc[ciudad, "population_total"]/1000
    plt.text(ciudades[indice], poblacion + 50, f"{poblacion}", ha="center")

# Segunda figura
plt.subplot(2, 2, 2)

plt.hist(df["area_total_km2"], color="steelblue", alpha=0.7, bins=50, label="Hist Area")

plt.xlabel("Superficie (km^2)", fontdict=dict(family="Bradley Hand ITC", size=18))
plt.ylabel("Número de Ciudades", fontdict=dict(family="Bradley Hand ITC", size=18))
plt.legend()

# Tercera figura
plt.subplot(2, 2, 3)

plt.scatter(df["area_water_km2"], df["population_total"]/1000, alpha=0.5, color="green")

plt.xlabel("Área de agua en la ciudad (km^2)")
plt.ylabel("Población (miles habitantes)")
plt.title("Población por kilómetro cuadrado de agua")

outlier_1 = ciudades_mas_pobladas.population_total.max()
outlier_2_y = ciudades_mas_pobladas.population_total.nlargest(2).iloc[1]
outlier_1_x = df.loc[df.population_total == outlier_1, "area_water_km2"].values[0]
outlier_2_x = df.loc[df.population_total == outlier_2_y, "area_water_km2"].values[0]

xytext = (60, 3500)
text = "Outliers"

plt.annotate(xy = (outlier_1_x, outlier_1_y/1000),
             xytext = xytext,
             text = text,
             arrowprops = dict(arrowstyle = "->"))

plt.annotate(xy = (outlier_2_x, outlier_2_y/1000),
             xytext = xytext,
             text = " " * len(text),
             arrowprops = dict(arrowstyle = "<->"))

# Cuarta figura
plt.subplot(2, 2, 4)

plt.boxplot(df["elevation_m"],
            vert = False,
            boxprops = dict(facecolor = "red"),
            medianprops = dict(color = "black"),
            patch_artist = True)

plt.xlabel("Altitud (m)")
plt.title("Diagrama de caja de la Altitud de las ciudades de California")
plt.yticks([])

plt.savefig("practica_obligatoria.png", bbox_inches="tight")

plt.show()

# %% [markdown]
# #### #1.3
#
# Graba la figura en un archivo .png y sube el archivo a tu repositorio personal junto con el notebook.

# %%
plt.savefig("practica_obligatoria.png", bbox_inches="tight")
plt.show()
